# %%
# 파이썬 ≥3.5 필수
import sys
assert sys.version_info >= (3, 5)

# 사이킷런 ≥0.20 필수
import sklearn
assert sklearn.__version__ >= "0.20"

# 공통 모듈 임포트
import numpy as np
import os

# 깔금한 그래프 출력을 위해
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

import arrow
import pandas as pd
import pickle
from IPython.display import display
from sklearn.preprocessing import FunctionTransformer
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer, OneHotEncoder, StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from tpot import TPOTRegressor

from bigquery_worker import BigqueryWorker
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
bigquery_worker = BigqueryWorker()
try:
    with open('datasets/df1.pickle', 'rb') as f:
        df1 = pickle.load(f)
except:
  df1 = bigquery_worker.get_daily_info_all('daily_items_indicator_info_all').drop_duplicates(['itemname', 'date'], 'first')
try:
    with open('datasets/df2.pickle', 'rb') as f:
        df2 = pickle.load(f)
except:
  df2 = bigquery_worker.get_daily_info_all('daily_items_info_all', start_date='2015-09-01').drop_duplicates(['itemname', 'date'], 'first')
df3 = bigquery_worker.get_itemcodes_info()
df4 = pd.concat([
    bigquery_worker.get_daily_item_info(('kospi', '코스피', 'kospi')),
    bigquery_worker.get_daily_item_info(('kosdaq', '코스닥', 'kosdaq')),
])

display(df1, df2, df3, df4)
# Out:
#          itemname       date     PER     PBR     PCR     PSR    ROE    ROA  \
# 0           네패스아크 2020-11-17  16.624   9.985  13.267   4.869    NaN    NaN
# 1           네패스아크 2020-11-18  15.357   9.223  12.256   4.497    NaN    NaN
# 2           네패스아크 2020-11-19  16.387   9.843  13.079   4.799    NaN    NaN
# 3           네패스아크 2020-11-20  17.998  10.810  14.364   5.271    NaN    NaN
# 4             아난티 2020-11-10 -14.982   2.050 -34.245  16.323 -13.52  -4.91
# ...           ...        ...     ...     ...     ...     ...    ...    ...
# 2163145      와이오엠 2016-08-22  -6.012   4.002     NaN     NaN -67.41 -27.73
# 2163146      슈프리마 2016-07-01   0.000   2.552     NaN     NaN    NaN    NaN
# 2163147  아이에이네트웍스 2016-08-01 -91.524   4.665     NaN     NaN  -7.51  -1.28
# 2163148      와이오엠 2016-09-02  -6.012   4.002     NaN     NaN -67.41 -27.73
# 2163149      와이오엠 2016-03-18 -12.299   8.187     NaN     NaN -67.41 -27.73
#
#           OPROA   OPROE  EV_EBITDA   GP_A          NOS
# 0        45.815  230.38        1.7  0.614  243268200.0
# 1        45.815  230.38        1.7  0.614  224724500.0
# 2        45.815  230.38        1.7  0.614  239810900.0
# 3        45.815  230.38        1.7  0.614  263383400.0
# 4        -2.524   -6.78       39.9  0.024  711916670.0
# ...         ...     ...        ...    ...          ...
# 2163145   0.000    0.00        NaN  0.000   59248400.0
# 2163146   0.000    0.00        NaN  0.000  196824000.0
# 2163147   0.000    0.00        NaN  0.000   35637724.0
# 2163148   0.000    0.00        NaN  0.000   59248400.0
# 2163149   0.000    0.00        NaN  0.000  121197830.0
#
# [2163150 rows x 13 columns]
#              itemname       date   open   high    low  close  volume
# 0                  WI 2017-09-21   1104   1145   1024   1024  238155
# 1                  WI 2019-07-03   1784   1814   1780   1792   57206
# 2                  WI 2020-02-05   1820   1840   1780   1792   50494
# 3                  WI 2016-03-07   2800   2908   2779   2816  690287
# 4                  WI 2019-01-02   1849   1849   1754   1793   27881
# ...               ...        ...    ...    ...    ...    ...     ...
# 2557905  피엔케이피부임상연구센타 2020-10-30  21800  23150  21750  22250  126879
# 2557906  피엔케이피부임상연구센타 2020-09-22  23500  23550  22150  22250  151167
# 2557907  피엔케이피부임상연구센타 2020-10-29  21950  22350  21300  21750   68232
# 2557908  피엔케이피부임상연구센타 2020-09-21  25400  25850  23400  23800  161173
# 2557909  피엔케이피부임상연구센타 2020-10-19  21300  22050  20650  21500   82484
#
# [2557910 rows x 7 columns]
#      itemcode itemname  market                            sector  \
# 0      950140    잉글우드랩  kosdaq                       기타 화학제품 제조업
# 1      900100    뉴프라이드  kosdaq                  자동차 부품 및 내장품 판매업
# 2      950200      소마젠  kosdaq            그외 기타 전문, 과학 및 기술 서비스업
# 3      950160   코오롱티슈진  kosdaq             기초 의약물질 및 생물학적 제제 제조업
# 4      950130   엑세스바이오  kosdaq             의료용품 및 기타 의약 관련제품 제조업
# ...       ...      ...     ...                               ...
# 2243   006220     제주은행   kospi                         은행 및 저축기관
# 2244   089590     제주항공   kospi                         항공 여객 운송업
# 2245   066110       한프  kosdaq                    컴퓨터 및 주변장치 제조업
# 2246   032350   롯데관광개발   kospi                여행사 및 기타 여행보조 서비스업
# 2247   035720      카카오   kospi  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업
#
#                        main_product listing_date settlement_month  \
# 0                     기초화장품(화장품 제조)   2016-10-14              12월
# 1                   인터모달 신생 및 재생타이어   2010-04-21              12월
# 2           유전체 분석 서비스 (NGS, CES 등)   2020-07-13              12월
# 3                          골관절염 치료제   2017-11-06              12월
# 4     말라리아 진단키트(RDT), HIV 진단키트(RDT)   2013-05-30              12월
# ...                             ...          ...              ...
# 2243                은행업무,외국환업무,신탁업무   1972-12-28              12월
# 2244               여객운송서비스, 화물운송서비스   2015-11-06              12월
# 2245                       OPC Drum   2002-07-16              12월
# 2246      국내외여행알선,관광개발,전세운수,항공권매매대행   2006-06-08              12월
# 2247                인터넷 서비스(인터넷 광고)   2017-07-10              12월
#
#      representative_name                     homepage     area
# 0                    조현철  http://www.englewoodlab.com       미국
# 1               John Lee        http://www.npcims.com       미국
# 2      Ryan W. Kim (김운봉)                         None       미국
# 3               노문종, 한성수        http://tissuegene.com       미국
# 4                    최영호     http://www.accessbio.net       미국
# ...                  ...                          ...      ...
# 2243                 서현주    http://www.e-jejubank.com  제주특별자치도
# 2244                 김이배       http://www.jejuair.net  제주특별자치도
# 2245                 유한성  http://www.baiksanopc.co.kr  제주특별자치도
# 2246        김기병, 백현, 김한준         http://lottetour.com  제주특별자치도
# 2247            여민수, 조수용     http://www.kakaocorp.com  제주특별자치도
#
# [2248 rows x 10 columns]
#            itemname  open  high   low  close      volume
# date
# 2000-01-04    kospi  1028  1066  1016   1059   195899000
# 2000-01-05    kospi  1006  1047   984    986   257696000
# 2000-01-06    kospi  1013  1014   953    960   203524000
# 2000-01-07    kospi   949   970   930    948   215664000
# 2000-01-10    kospi   979   994   965    987   240175000
# ...             ...   ...   ...   ...    ...         ...
# 2020-11-16   kosdaq   843   849   841    847  1619880000
# 2020-11-17   kosdaq   846   846   836    839  1789493000
# 2020-11-18   kosdaq   842   852   840    851  2330367000
# 2020-11-19   kosdaq   851   860   849    859  2249201000
# 2020-11-20   kosdaq   863   870   861    870  2148982000
#
# [10314 rows x 6 columns]

# %%
def add_dm_dmv_columns(origin_df):
    df = origin_df.copy()
    nums = [5, 10, 20, 50, 120, 300]
    for n in nums:
        gdf = df.sort_values(['itemname', 'date']).groupby('itemname')
        df[f'{n}dm'] = gdf['close'].rolling(n).mean().reset_index(0, drop=True)
        df[f'{n}dmv'] = gdf['volume'].rolling(n).mean().reset_index(0, drop=True)
    for i, x in enumerate(nums):
        for y in nums[i + 1:]:
            df[f'{x}dm/{y}dm'] = df[f'{x}dm'] / df[f'{y}dm']
            df[f'{x}dmv/{y}dmv'] = df[f'{x}dmv'] / df[f'{y}dmv']
    df = df.drop([f'{n}dm' for n in nums] + [f'{n}dmv' for n in nums], axis=1)
    return df
        

dm_dmv_adder = FunctionTransformer(add_dm_dmv_columns)
df_1, df_2, df_3, df_4 = df1.copy(), dm_dmv_adder.fit_transform(df2), df3.copy(), dm_dmv_adder.fit_transform(df4)

# %%
def make_df(start_date='2017-01-02', end_date='2020-08-23', ror_months=3, move_days=30):
    date = arrow.get(start_date)
    df = pd.DataFrame()
    while date < arrow.get(end_date):        
        date2 = df_1[df_1.date >= date.shift(months=ror_months).format('YYYY-MM-DD')].date.min()
        date_str = date.format('YYYY-MM-DD')
        temp = df_1[df_1.date == date_str]
        temp2 = df_2[df_2.date == date_str].drop('date', axis=1)
        temp = temp.merge(temp2, how='inner', left_on='itemname', right_on='itemname').set_index('itemname')
        temp['ror'] = df_2[df_2.date == date2].set_index('itemname').close / temp.close
        temp[['market', 'sector', 'area']] = df_3.set_index('itemname')[['market', 'sector', 'area']]
        temp = temp.drop(['open', 'high', 'low', 'close', 'volume'], axis=1).reset_index()
        temp4 = df_4.loc[date_str].reset_index().drop(['open', 'high', 'low', 'close', 'volume'], axis=1)
        temp = temp.merge(
            temp4.rename(columns={'itemname': 'market'}), how='inner', left_on=['market', 'date'], right_on=['market', 'date'],
            suffixes=('_item', '_market')
        )
        df = df.append(temp, ignore_index=True)
        date = arrow.get(df1[df1.date >= date.shift(days=move_days).format('YYYY-MM-DD')].date.min())
    df = df.dropna()
    df = df.reset_index(drop=True)
    df['month'] = df['date'].dt.month.astype(str)
    return df

# %%
def split_fit(df, model):
    train_set = df[df.date < '2020-01-01'].set_index(['itemname', 'date'])
    test_set = df[df.date > '2020-01-01'][df.sector.isin(train_set.sector.unique())].set_index(['itemname', 'date'])
    X_train, X_test, y_train, y_test = train_set.drop(['ror'], axis=1), test_set.drop(['ror'], axis=1),\
        train_set['ror'].copy(), test_set['ror'].copy()
    cat_features = ["market", "sector", "area", "month"]
    num_features = list(set(X_train.columns) - set(cat_features))
    num_pipe = make_pipeline(StandardScaler(), Normalizer())
    pre_pipe = make_column_transformer((num_pipe, num_features), (OneHotEncoder(), cat_features))
    full_pipe = make_pipeline(pre_pipe, model)
    if isinstance(model, TPOTRegressor):
        X_train = pre_pipe.fit_transform(X_train).toarray()
        X_test = pre_pipe.transform(X_test).toarray()
        model.fit(X_train, y_train.to_numpy())
        return model, X_test, y_test.to_numpy()
    full_pipe.fit(X_train, y_train)
    return full_pipe, X_test, y_test

# %%
df = make_df(ror_months=1)
pipe, X_test, y_test = split_fit(df, model=LGBMRegressor(random_state=42))
predictions = pipe.predict(X_test)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
display(ror_months, rmse)
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 9
# 0.25881082134696054

# %%
for ror_months in [1, 3, 6, 9]:
    df = make_df(ror_months=ror_months)
    pipe, X_test, y_test = split_fit(df, model=LGBMRegressor(random_state=42))
    predictions = pipe.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    rmse = np.sqrt(mse)
    display(ror_months, rmse)
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 1
# 0.21134151153515138
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 3
# 0.41201900256276747
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 6
# 0.7616103734583922
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 9
# 0.8589417582403703

# %%
regressor_config_dict=dict()
regressor_config_dict['lightgbm.LGBMRegressor'] = {
    'boosting_type': ['gbdt', 'dart'],
    'learning_rate': [0.01, 0.05, 0.1],
}
regressor_config_dict['xgboost.XGBRegressor'] = {
    'n_estimators': [100],
    'max_depth': range(1, 11),
    'learning_rate': [1e-3, 1e-2, 1e-1, 0.5, 1.],
    'subsample': np.arange(0.05, 1.01, 0.05),
    'min_child_weight': range(1, 21),
    'nthread': [1],
    'objective': ['reg:squarederror']
}

# %%
df
# Out:
#        itemname       date      PER    PBR     PCR    PSR    ROE    ROA  \
# 0          이화전기 2017-01-02  -27.895  1.963 -33.125  2.585  -7.49  -5.01
# 1            코콤 2017-01-02   23.908  1.779  20.607  1.516   7.89   6.34
# 2          플랜티넷 2017-01-02   24.178  0.833  14.205  2.275   3.75   3.73
# 3        라이브플렉스 2017-01-02    3.114  0.987   3.025  1.972  38.07  26.79
# 4       마이크로컨텍솔 2017-01-02 -348.000  1.425  55.680  2.125  -0.41  -0.54
# ...         ...        ...      ...    ...     ...    ...    ...    ...
# 304487      한네트 2020-08-18    0.000  1.144   6.622  1.546   3.19   1.73
# 304488    에이디칩스 2020-08-18    0.000  0.962  -1.780  1.171 -46.50 -30.37
# 304489    케이씨에스 2020-08-18    0.000  2.338  15.208  1.224  14.10   8.49
# 304490     흥구석유 2020-08-18    0.000  1.203  10.613  0.620  11.25  10.44
# 304491     NE능률 2020-08-18    0.000  0.701   4.586  0.536   1.26   0.77
#
#         OPROA  OPROE  ...  20dmv/120dmv_market  20dm/300dm_market  \
# 0       0.978  1.357  ...             0.834743           1.018601
# 1       7.470  9.362  ...             0.834743           1.018601
# 2       5.060  5.497  ...             0.834743           1.018601
# 3       2.091  3.068  ...             0.834743           1.018601
# 4      -1.342 -1.463  ...             0.834743           1.018601
# ...       ...    ...  ...                  ...                ...
# 304487  0.000  0.000  ...             0.971428           1.113518
# 304488  0.000  0.000  ...             0.971428           1.113518
# 304489  0.000  0.000  ...             0.971428           1.113518
# 304490  0.000  0.000  ...             0.971428           1.113518
# 304491  0.000  0.000  ...             0.971428           1.113518
#
#         20dmv/300dmv_market  50dm/120dm_market  50dmv/120dmv_market  \
# 0                  0.738856           0.991538             0.850734
# 1                  0.738856           0.991538             0.850734
# 2                  0.738856           0.991538             0.850734
# 3                  0.738856           0.991538             0.850734
# 4                  0.738856           0.991538             0.850734
# ...                     ...                ...                  ...
# 304487             1.259182           1.091686             0.956106
# 304488             1.259182           1.091686             0.956106
# 304489             1.259182           1.091686             0.956106
# 304490             1.259182           1.091686             0.956106
# 304491             1.259182           1.091686             0.956106
#
#         50dm/300dm_market  50dmv/300dmv_market  120dm/300dm_market  \
# 0                1.007705             0.753011            1.016305
# 1                1.007705             0.753011            1.016305
# 2                1.007705             0.753011            1.016305
# 3                1.007705             0.753011            1.016305
# 4                1.007705             0.753011            1.016305
# ...                   ...                  ...                 ...
# 304487           1.068877             1.239323            0.979107
# 304488           1.068877             1.239323            0.979107
# 304489           1.068877             1.239323            0.979107
# 304490           1.068877             1.239323            0.979107
# 304491           1.068877             1.239323            0.979107
#
#         120dmv/300dmv_market  month
# 0                   0.885131      1
# 1                   0.885131      1
# 2                   0.885131      1
# 3                   0.885131      1
# 4                   0.885131      1
# ...                      ...    ...
# 304487              1.296218      8
# 304488              1.296218      8
# 304489              1.296218      8
# 304490              1.296218      8
# 304491              1.296218      8
#
# [304492 rows x 78 columns]

# %%
for ror_months in range(3, 10, 3):
    df = make_df(ror_months=ror_months)
    for model in [LGBMRegressor(random_state=42), XGBRegressor(random_state=42), MLPRegressor(random_state=42)]:
        pipe, X_test, y_test = split_fit(df, model=model)
        predictions = pipe.predict(X_test)
        mse = mean_squared_error(y_test, predictions)
        rmse = np.sqrt(mse)
        display(ror_months, model, rmse)
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 3
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=42, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# 0.4317755836038961
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [21:16:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)
# 0.4312989001418568
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 3
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=200,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=42, shuffle=True, solver='adam',
#              tol=0.0001, validation_fraction=0.1, verbose=False,
#              warm_start=False)
# 0.49122526437816194
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 6
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=42, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# 0.80700503933476
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [21:22:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 6
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)
# 0.818661092668568
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 6
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=200,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=42, shuffle=True, solver='adam',
#              tol=0.0001, validation_fraction=0.1, verbose=False,
#              warm_start=False)
# 0.8389800767565649
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 9
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=42, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# 0.8003529275802942
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [21:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 9
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)
# 0.8205824849189886
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 9
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=200,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=42, shuffle=True, solver='adam',
#              tol=0.0001, validation_fraction=0.1, verbose=False,
#              warm_start=False)
# 0.8430186137580383

# %%
from sklearn.model_selection import TimeSeriesSplit
tscv = TimeSeriesSplit()
for train_index, test_index in tscv.split(df.set_index('date')):
    print("TRAIN:", train_index, "TEST:", test_index)
# Out:
# TRAIN: [    0     1     2 ... 50749 50750 50751] TEST: [ 50752  50753  50754 ... 101497 101498 101499]
# TRAIN: [     0      1      2 ... 101497 101498 101499] TEST: [101500 101501 101502 ... 152245 152246 152247]
# TRAIN: [     0      1      2 ... 152245 152246 152247] TEST: [152248 152249 152250 ... 202993 202994 202995]
# TRAIN: [     0      1      2 ... 202993 202994 202995] TEST: [202996 202997 202998 ... 253741 253742 253743]
# TRAIN: [     0      1      2 ... 253741 253742 253743] TEST: [253744 253745 253746 ... 304489 304490 304491]

# %%
TPOTRegressor?

# %%
model = TPOTRegressor(
    generations=3, population_size=10, verbosity=3, random_state=42, cv=TimeSeriesSplit(n_splits=3), n_jobs=-1, memory='auto'
)
df = make_df(ror_months=3)
model, X_test, y_test = split_fit(df, model=model)
predictions = model.predict(X_test)
display(np.sqrt(-model.score(X_test, y_test)))
display(ror_months, np.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 30 operators have been imported by TPOT.
# Version 0.11.6.post1 of tpot is outdated. Version 0.11.6.post2 was released 4 days ago.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=40.0, style=ProgressStyle(des…
# Skipped pipeline #1 due to time out. Continuing to the next pipeline.
# Skipped pipeline #7 due to time out. Continuing to the next pipeline.
# Skipped pipeline #9 due to time out. Continuing to the next pipeline.
# Skipped pipeline #13 due to time out. Continuing to the next pipeline.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# Skipped pipeline #20 due to time out. Continuing to the next pipeline.
# Skipped pipeline #22 due to time out. Continuing to the next pipeline.
# Skipped pipeline #24 due to time out. Continuing to the next pipeline.
# Skipped pipeline #26 due to time out. Continuing to the next pipeline.
# Skipped pipeline #28 due to time out. Continuing to the next pipeline.
#
# Generation 1 - Current Pareto front scores:
#
# -1	-0.07141961166659098	RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)
# Skipped pipeline #32 due to time out. Continuing to the next pipeline.
#
# Generation 2 - Current Pareto front scores:
#
# -1	-0.07065878589139543	ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #48 due to time out. Continuing to the next pipeline.
#
# Generation 3 - Current Pareto front scores:
#
# -1	-0.07065878589139543	ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)
#
# -2	-0.07036172337134579	RandomForestRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=13, DecisionTreeRegressor__min_samples_split=10), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)
# 0.3992670920731064
# 1
# 0.3992670920731064

# %%
model.fitted_pipeline_
# Out:
# Pipeline(memory=Memory(location=C:\Users\gsr27\AppData\Local\Temp\tmpg_k61gvb\joblib),
#          steps=[('stackingestimator',
#                  StackingEstimator(estimator=DecisionTreeRegressor(ccp_alpha=0.0,
#                                                                    criterion='mse',
#                                                                    max_depth=6,
#                                                                    max_features=None,
#                                                                    max_leaf_nodes=None,
#                                                                    min_impurity_decrease=0.0,
#                                                                    min_impurity_split=None,
#                                                                    min_samples_leaf=13,
#                                                                    min_samples_split=10,
#                                                                    min_weight_frac...
#                  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                        criterion='mse', max_depth=None,
#                                        max_features=0.05, max_leaf_nodes=None,
#                                        max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=7, min_samples_split=13,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=None,
#                                        oob_score=False, random_state=42,
#                                        verbose=0, warm_start=False))],
#          verbose=False)

# %%
model.pareto_front_fitted_pipelines_
# Out:
# {'ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)': Pipeline(memory=Memory(location=C:\Users\gsr27\AppData\Local\Temp\tmpg_k61gvb\joblib),
#           steps=[('elasticnetcv',
#                   ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=0.001,
#                                fit_intercept=True, l1_ratio=0.05, max_iter=1000,
#                                n_alphas=100, n_jobs=None, normalize=False,
#                                positive=False, precompute='auto',
#                                random_state=42, selection='cyclic', tol=0.1,
#                                verbose=0))],
#           verbose=False),
#  'RandomForestRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=13, DecisionTreeRegressor__min_samples_split=10), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': Pipeline(memory=Memory(location=C:\Users\gsr27\AppData\Local\Temp\tmpg_k61gvb\joblib),
#           steps=[('stackingestimator',
#                   StackingEstimator(estimator=DecisionTreeRegressor(ccp_alpha=0.0,
#                                                                     criterion='mse',
#                                                                     max_depth=6,
#                                                                     max_features=None,
#                                                                     max_leaf_nodes=None,
#                                                                     min_impurity_decrease=0.0,
#                                                                     min_impurity_split=None,
#                                                                     min_samples_leaf=13,
#                                                                     min_samples_split=10,
#                                                                     min_weight_frac...
#                   RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                         criterion='mse', max_depth=None,
#                                         max_features=0.05, max_leaf_nodes=None,
#                                         max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=7, min_samples_split=13,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=42,
#                                         verbose=0, warm_start=False))],
#           verbose=False)}

# %%
model.evaluated_individuals_
# Out:
# {'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7500000000000001, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07256558824675415},
#  'AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.7392513624874805},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07149436260914359},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07560646055933189},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=20, GradientBoostingRegressor__min_samples_split=3, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=1.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07154230090533052},
#  'LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07882159718549724},
#  'AdaBoostRegressor(FastICA(input_matrix, FastICA__tol=0.4), AdaBoostRegressor__learning_rate=0.5, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=1.0, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.29014792619706753},
#  'ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.01)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)',
#    'RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)'),
#   'operator_count': 2,
#   'internal_cv_score': -0.07354788476232195},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7500000000000001, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07141961166659098},
#  'ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07185089658059206},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.9000000000000001, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'GradientBoostingRegressor(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.9000000000000001, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=19, RandomForestRegressor__n_estimators=100), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=20, GradientBoostingRegressor__min_samples_split=3, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=1.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=20, GradientBoostingRegressor__min_samples_split=3, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=1.0)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'AdaBoostRegressor(LassoLarsCV(FastICA(input_matrix, FastICA__tol=0.4), LassoLarsCV__normalize=True), AdaBoostRegressor__learning_rate=0.5, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('AdaBoostRegressor(FastICA(input_matrix, FastICA__tol=0.4), AdaBoostRegressor__learning_rate=0.5, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)',),
#   'operator_count': 3,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=11, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'DecisionTreeRegressor(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.01)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07841242632525748},
#  'LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=1e-05)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07796970119911657},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7000000000000001, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'DecisionTreeRegressor(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.2, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10), DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07573118676122177},
#  'ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.01)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 1,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)',
#    'RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)'),
#   'operator_count': 2,
#   'internal_cv_score': -0.07164702438373026},
#  'RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=7, RandomForestRegressor__n_estimators=100)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07256558824675415},
#  'RandomForestRegressor(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=polynomial, Nystroem__n_components=2), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)': {'generation': 2,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07420436132325935},
#  'ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)': {'generation': 2,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07065878589139543},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=9, DecisionTreeRegressor__min_samples_leaf=10, DecisionTreeRegressor__min_samples_split=11)': {'generation': 2,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=1.0, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.08427375593462116},
#  'DecisionTreeRegressor(LassoLarsCV(input_matrix, LassoLarsCV__normalize=False), DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.08049517098210156},
#  'LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.001, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.01)': {'generation': 3,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.01)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07882357734929363},
#  'ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.8500000000000001, ElasticNetCV__tol=0.1)': {'generation': 3,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.07112071861159562},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 1,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)',
#    'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)'),
#   'operator_count': 1,
#   'internal_cv_score': -0.07149436260914359},
#  'ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)': {'generation': 3,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07326486970173422},
#  'ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=6, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07751490134121042},
#  'RandomForestRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=13, DecisionTreeRegressor__min_samples_split=10), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07036172337134579},
#  'ElasticNetCV(RandomForestRegressor(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.8, RandomForestRegressor__min_samples_leaf=13, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)',),
#   'operator_count': 3,
#   'internal_cv_score': -inf},
#  'RandomForestRegressor(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.1, ExtraTreesRegressor__min_samples_leaf=4, ExtraTreesRegressor__min_samples_split=6, ExtraTreesRegressor__n_estimators=100), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.07055988320175961},
#  'ElasticNetCV(RBFSampler(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), RBFSampler__gamma=0.9500000000000001), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.01)': {'generation': 3,
#   'mutation_count': 2,
#   'crossover_count': 1,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.01)',),
#   'operator_count': 3,
#   'internal_cv_score': -0.07092030265640561}}

# %%
model.export('tpot_pipeline_20201205_3m_1.py')

# %%
ror_months = 3
df = make_df(ror_months=ror_months)
date = '2020-11-20'
temp = df_2[df_2.date == date].drop(['date', 'open', 'high', 'low', 'close', 'volume'], axis=1)
pdf = df_1[df_1.date == date].merge(temp, how='inner', left_on='itemname', right_on='itemname').set_index('itemname')
pdf[['market', 'sector', 'area']] = df_3.set_index('itemname')[['market', 'sector', 'area']]
temp4 = df_4.loc[date].reset_index(drop=True).drop(['open', 'high', 'low', 'close', 'volume'], axis=1).rename(
    columns={'itemname': 'market'})
pdf = pdf.reset_index().merge(temp4, how='inner', left_on='market', right_on='market', suffixes=('_item', '_market'))
pdf['month'] = pdf['date'].dt.month.astype(str)
pdf = pdf[pdf.sector.isin(df.sector.unique())].dropna().set_index(['itemname', 'date'])
predictions = model.predict(pdf)
pdf['pred_ror'] = predictions
pdf['pred_ror_rank'] = pdf['pred_ror'].rank(ascending=False)
pdf = pdf.sort_values('pred_ror_rank')
display(ror_months, model, pdf.head(30))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-8d0b0b1736db> in <module>
#      10 pdf['month'] = pdf['date'].dt.month.astype(str)
#      11 pdf = pdf[pdf.sector.isin(df.sector.unique())].dropna().set_index(['itemname', 'date'])
# ---> 12 display(pdf.columns.tolist() == X_test.columns.tolist())
#      13 predictions = model.predict(pdf)
#      14 pdf['pred_ror'] = predictions
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
train_set = df[df.date < '2020-01-01'].set_index(['itemname', 'date'])
test_set = df[df.date > '2020-01-01'][df.sector.isin(train_set.sector.unique())].set_index(['itemname', 'date'])
X_train, X_test, y_train, y_test = train_set.drop(['ror'], axis=1), test_set.drop(['ror'], axis=1),\
    train_set['ror'].copy(), test_set['ror'].copy()
cat_features = ["market", "sector", "area", "month"]
num_features = list(set(X_train.columns) - set(cat_features))
num_pipe = make_pipeline(StandardScaler(), Normalizer())
pre_pipe = make_column_transformer((num_pipe, num_features), (OneHotEncoder(), cat_features))
pre_pipe.fit(X_train)
pdf = pdf[pdf.sector.isin(X_train.sector.unique())]
pdf_trans = pre_pipe.transform(pdf)
predictions = model.predict(pdf_trans.toarray())
pdf['pred_ror'] = predictions
pdf['pred_ror_rank'] = pdf['pred_ror'].rank(ascending=False)
pdf = pdf.sort_values('pred_ror_rank')
display(ror_months, model, pdf.head(30))
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 3
# TPOTRegressor(config_dict=None, crossover_rate=0.1,
#               cv=TimeSeriesSplit(max_train_size=None, n_splits=3),
#               disable_update_check=False, early_stop=None, generations=3,
#               log_file=None, max_eval_time_mins=5, max_time_mins=None,
#               memory='auto', mutation_rate=0.9, n_jobs=-1, offspring_size=None,
#               periodic_checkpoint_folder=None, population_size=10,
#               random_state=42, scoring=None, subsample=1.0, template=None,
#               use_dask=False, verbosity=3, warm_start=False)
#                           PER    PBR      PCR    PSR     ROE     ROA  OPROA  \
# itemname  date
# 동양        2020-11-20   12.050  0.305   25.104  1.000   3.000   2.350  2.009
# 성신양회      2020-11-20    2.246  0.441    7.767  0.551  20.170   7.660  9.247
# 세이브존I&C   2020-11-20 -245.000  0.261   10.929  1.191  -0.110  -0.090  1.567
# 부산산업      2020-11-20   37.916  2.249   24.590  1.627   5.990   4.240  4.655
# 아세아시멘트    2020-11-20    4.915  0.320    6.780  0.660   6.560   2.810  5.583
# 한일현대시멘트   2020-11-20    0.000  2.125    7.700  1.131  21.690   7.450  0.000
# 텔코웨어      2020-11-20   15.228  0.820  113.208  5.553   7.140   6.640  5.190
# SH에너지화학   2020-11-20  -34.375  0.994  -14.224  1.384  -2.820  -2.190 -3.041
# 하이스틸      2020-11-20   17.120  0.251   15.734  0.279   1.470   0.770  1.515
# SBS미디어홀딩스 2020-11-20 -223.750  0.423  -99.444  3.653  -0.220  -0.270 -1.217
# SIMPAC    2020-11-20    8.209  0.345   10.897  0.925   4.430   2.790  2.585
# S&T중공업    2020-11-20 -230.417  0.274   12.890  0.905  -0.120  -0.090 -0.428
# 성보화학      2020-11-20  -27.372  0.579   16.550  1.686  -2.150  -1.860 -5.896
# 한국석유공업    2020-11-20    7.806  0.420    8.319  0.173   5.570   2.520  5.968
# 한미약품      2020-11-20  -31.442  5.088   87.403  7.296  -0.168  -0.063 -0.065
# 삼호개발      2020-11-20    5.421  0.517   12.677  0.583  10.050   6.400  4.560
# 대호에이엘     2020-11-20    0.000  2.359 -109.524  0.531 -12.620  -4.140  0.000
# 대원전선      2020-11-20    0.000  0.897   19.167  0.293  -0.020  -0.010  0.818
# 한국화장품제조   2020-11-20    0.000  3.787  160.895  2.450  -3.030  -1.910  0.000
# 삼성공조      2020-11-20   40.875  0.244   11.179  1.136   0.600   0.490 -0.624
# 한일철강      2020-11-20   -5.933  0.264  -22.171  0.484  -4.520  -1.990 -1.763
# 주연테크      2020-11-20  -97.083  1.435   37.581  1.596  -1.430  -1.590 -0.771
# 이수페타시스    2020-11-20   14.323  2.209   23.305  0.689  16.980   2.670  3.028
# 유수홀딩스     2020-11-20  1.107577           28.0
# 쌍방울       2020-11-20  1.107560           29.0
# 화인베스틸     2020-11-20  1.106043           30.0
#
# [30 rows x 77 columns]

# %%
model = TPOTRegressor(
    generations=3, population_size=10, verbosity=3, random_state=42, cv=TimeSeriesSplit(n_splits=3), n_jobs=-1, memory='auto'
)
df = make_df(ror_months=9)
model, X_test, y_test = split_fit(df, model=model)
predictions = model.predict(X_test)
display(np.sqrt(-model.score(X_test, y_test)))
display(ror_months, np.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# 30 operators have been imported by TPOT.
# Version 0.11.6.post1 of tpot is outdated. Version 0.11.6.post2 was released 4 days ago.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=40.0, style=ProgressStyle(des…
# Skipped pipeline #1 due to time out. Continuing to the next pipeline.
# Skipped pipeline #7 due to time out. Continuing to the next pipeline.
# Skipped pipeline #9 due to time out. Continuing to the next pipeline.
# Skipped pipeline #13 due to time out. Continuing to the next pipeline.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# Skipped pipeline #18 due to time out. Continuing to the next pipeline.
# Skipped pipeline #21 due to time out. Continuing to the next pipeline.
# Skipped pipeline #23 due to time out. Continuing to the next pipeline.
# Skipped pipeline #25 due to time out. Continuing to the next pipeline.
# Skipped pipeline #27 due to time out. Continuing to the next pipeline.
# Skipped pipeline #29 due to time out. Continuing to the next pipeline.
#
# Generation 1 - Current Pareto front scores:
#
# -1	-0.25696149058112155	RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)
#
# -2	-0.25168761777286636	ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)
# Skipped pipeline #32 due to time out. Continuing to the next pipeline.
# Skipped pipeline #35 due to time out. Continuing to the next pipeline.
# Skipped pipeline #39 due to time out. Continuing to the next pipeline.
# Skipped pipeline #41 due to time out. Continuing to the next pipeline.
#
# Generation 2 - Current Pareto front scores:
#
# -1	-0.2565471228529684	DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=3, DecisionTreeRegressor__min_samples_leaf=20, DecisionTreeRegressor__min_samples_split=14)
#
# -2	-0.24894694847126742	LinearSVR(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=polynomial, Nystroem__n_components=2), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)
# Skipped pipeline #50 due to time out. Continuing to the next pipeline.
# Skipped pipeline #52 due to time out. Continuing to the next pipeline.
#
# Generation 3 - Current Pareto front scores:
#
# -1	-0.25079713866750586	ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)
#
# -2	-0.24894694847126742	LinearSVR(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=polynomial, Nystroem__n_components=2), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)
#
# -3	-0.24728295934143718	ElasticNetCV(RBFSampler(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), RBFSampler__gamma=0.9500000000000001), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)
# 0.8652586105369425
# 3
# 0.8652586105369425

# %%
model.fitted_pipeline_
# Out:
# Pipeline(memory=Memory(location=C:\Users\gsr27\AppData\Local\Temp\tmpxng60pkj\joblib),
#          steps=[('stackingestimator',
#                  StackingEstimator(estimator=GradientBoostingRegressor(alpha=0.85,
#                                                                        ccp_alpha=0.0,
#                                                                        criterion='friedman_mse',
#                                                                        init=None,
#                                                                        learning_rate=0.5,
#                                                                        loss='lad',
#                                                                        max_depth=1,
#                                                                        max_features=0.5,
#                                                                        max_leaf_nodes=None,
#                                                                        min_impurity_decrease=0.0,
#                                                                        min_impurity_split...
#                                                                        warm_start=False))),
#                 ('rbfsampler',
#                  RBFSampler(gamma=0.9500000000000001, n_components=100,
#                             random_state=42)),
#                 ('elasticnetcv',
#                  ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=0.001,
#                               fit_intercept=True, l1_ratio=0.45, max_iter=1000,
#                               n_alphas=100, n_jobs=None, normalize=False,
#                               positive=False, precompute='auto',
#                               random_state=42, selection='cyclic', tol=0.001,
#                               verbose=0))],
#          verbose=False)

# %%
model.pareto_front_fitted_pipelines_
# Out:
# {'ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)': Pipeline(memory=Memory(location=C:\Users\gsr27\AppData\Local\Temp\tmpxng60pkj\joblib),
#           steps=[('elasticnetcv',
#                   ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=0.001,
#                                fit_intercept=True, l1_ratio=0.05, max_iter=1000,
#                                n_alphas=100, n_jobs=None, normalize=False,
#                                positive=False, precompute='auto',
#                                random_state=42, selection='cyclic', tol=0.1,
#                                verbose=0))],
#           verbose=False),
#  'LinearSVR(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=polynomial, Nystroem__n_components=2), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': Pipeline(memory=Memory(location=C:\Users\gsr27\AppData\Local\Temp\tmpxng60pkj\joblib),
#           steps=[('nystroem',
#                   Nystroem(coef0=None, degree=None, gamma=0.30000000000000004,
#                            kernel='polynomial', kernel_params=None,
#                            n_components=2, random_state=42)),
#                  ('linearsvr',
#                   LinearSVR(C=1.0, dual=True, epsilon=0.1, fit_intercept=True,
#                             intercept_scaling=1.0, loss='epsilon_insensitive',
#                             max_iter=1000, random_state=42, tol=0.1,
#                             verbose=0))],
#           verbose=False),
#  'ElasticNetCV(RBFSampler(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), RBFSampler__gamma=0.9500000000000001), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)': Pipeline(memory=Memory(location=C:\Users\gsr27\AppData\Local\Temp\tmpxng60pkj\joblib),
#           steps=[('stackingestimator',
#                   StackingEstimator(estimator=GradientBoostingRegressor(alpha=0.85,
#                                                                         ccp_alpha=0.0,
#                                                                         criterion='friedman_mse',
#                                                                         init=None,
#                                                                         learning_rate=0.5,
#                                                                         loss='lad',
#                                                                         max_depth=1,
#                                                                         max_features=0.5,
#                                                                         max_leaf_nodes=None,
#                                                                         min_impurity_decrease=0.0,
#                                                                         min_impurity_split...
#                                                                         warm_start=False))),
#                  ('rbfsampler',
#                   RBFSampler(gamma=0.9500000000000001, n_components=100,
#                              random_state=42)),
#                  ('elasticnetcv',
#                   ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=0.001,
#                                fit_intercept=True, l1_ratio=0.45, max_iter=1000,
#                                n_alphas=100, n_jobs=None, normalize=False,
#                                positive=False, precompute='auto',
#                                random_state=42, selection='cyclic', tol=0.001,
#                                verbose=0))],
#           verbose=False)}

# %%
model.evaluated_individuals_
# Out:
# {'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7500000000000001, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -0.2539304188346559},
#  'AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -2.603527389991929},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.25696149058112155},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.29472473618103884},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=20, GradientBoostingRegressor__min_samples_split=3, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=1.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -0.25168761777286636},
#  'LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.2627701894056107},
#  'AdaBoostRegressor(FastICA(input_matrix, FastICA__tol=0.4), AdaBoostRegressor__learning_rate=0.5, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=1.0, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.49684968407724517},
#  'ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.01)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)',
#    'RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)'),
#   'operator_count': 2,
#   'internal_cv_score': -0.2707476129114728},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.7500000000000001, RandomForestRegressor__min_samples_leaf=11, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.2517170757848832},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.9000000000000001, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'GradientBoostingRegressor(RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.9000000000000001, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=19, RandomForestRegressor__n_estimators=100), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=20, GradientBoostingRegressor__min_samples_split=3, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=1.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=20, GradientBoostingRegressor__min_samples_split=3, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=1.0)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'AdaBoostRegressor(LassoLarsCV(FastICA(input_matrix, FastICA__tol=0.4), LassoLarsCV__normalize=True), AdaBoostRegressor__learning_rate=0.5, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('AdaBoostRegressor(FastICA(input_matrix, FastICA__tol=0.4), AdaBoostRegressor__learning_rate=0.5, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)',),
#   'operator_count': 3,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=11, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'DecisionTreeRegressor(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=8, DecisionTreeRegressor__min_samples_split=5)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.36468218174177464},
#  'AdaBoostRegressor(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'SGDRegressor(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), SGDRegressor__alpha=0.01, SGDRegressor__eta0=1.0, SGDRegressor__fit_intercept=False, SGDRegressor__l1_ratio=0.5, SGDRegressor__learning_rate=constant, SGDRegressor__loss=epsilon_insensitive, SGDRegressor__penalty=elasticnet, SGDRegressor__power_t=1.0)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 1,
#   'predecessor': ('ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.01)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.4912007867235697},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)': {'generation': 2,
#   'mutation_count': 0,
#   'crossover_count': 2,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.001)',
#    'ElasticNetCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.9500000000000001, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.01)'),
#   'operator_count': 2,
#   'internal_cv_score': -0.25424402084195824},
#  'LinearSVR(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=polynomial, Nystroem__n_components=2), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.24894694847126742},
#  'DecisionTreeRegressor(KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=21, KNeighborsRegressor__p=2, KNeighborsRegressor__weights=distance), DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=5)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)': {'generation': 2,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.75, ElasticNetCV__tol=0.01), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=16, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=3, DecisionTreeRegressor__min_samples_leaf=20, DecisionTreeRegressor__min_samples_split=14)': {'generation': 2,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=1.0, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.2565471228529684},
#  'LinearSVR(Normalizer(input_matrix, Normalizer__norm=l1), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=1.0, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 2,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=1.0, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.5028989540371485},
#  'DecisionTreeRegressor(XGBRegressor(input_matrix, XGBRegressor__learning_rate=0.01, XGBRegressor__max_depth=8, XGBRegressor__min_child_weight=13, XGBRegressor__n_estimators=100, XGBRegressor__nthread=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.25), DecisionTreeRegressor__max_depth=3, DecisionTreeRegressor__min_samples_leaf=20, DecisionTreeRegressor__min_samples_split=14)': {'generation': 3,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=3, DecisionTreeRegressor__min_samples_leaf=20, DecisionTreeRegressor__min_samples_split=14)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.2824088467234198},
#  'LinearSVR(input_matrix, LinearSVR__C=10.0, LinearSVR__dual=False, LinearSVR__epsilon=1.0, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.6578465216414655},
#  'ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)': {'generation': 3,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.05, ElasticNetCV__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.25079713866750586},
#  'LinearSVR(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.1, ExtraTreesRegressor__min_samples_leaf=4, ExtraTreesRegressor__min_samples_split=6, ExtraTreesRegressor__n_estimators=100), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.27427169793868367},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=14, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.55, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=7, RandomForestRegressor__min_samples_split=13, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'ElasticNetCV(RBFSampler(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), RBFSampler__gamma=0.9500000000000001), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)': {'generation': 3,
#   'mutation_count': 1,
#   'crossover_count': 2,
#   'predecessor': ('ElasticNetCV(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.5, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.2), ElasticNetCV__l1_ratio=0.45, ElasticNetCV__tol=0.001)',),
#   'operator_count': 3,
#   'internal_cv_score': -0.24728295934143718},
#  'LinearSVR(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.001, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=3, GradientBoostingRegressor__max_features=0.9500000000000001, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=19, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.4), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 3,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=polynomial, Nystroem__n_components=2), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.1, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.2522511888108165},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=1, DecisionTreeRegressor__min_samples_leaf=20, DecisionTreeRegressor__min_samples_split=14)': {'generation': 3,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=3, DecisionTreeRegressor__min_samples_leaf=20, DecisionTreeRegressor__min_samples_split=14)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.257746718755074}}

# %%
model.export('tpot_pipeline_20201205_9m_1.py')

# %%
ror_months = 9
df = make_df(ror_months=ror_months)
date = '2020-11-20'
temp = df_2[df_2.date == date].drop(['date', 'open', 'high', 'low', 'close', 'volume'], axis=1)
pdf = df_1[df_1.date == date].merge(temp, how='inner', left_on='itemname', right_on='itemname').set_index('itemname')
pdf[['market', 'sector', 'area']] = df_3.set_index('itemname')[['market', 'sector', 'area']]
temp4 = df_4.loc[date].reset_index(drop=True).drop(['open', 'high', 'low', 'close', 'volume'], axis=1).rename(
    columns={'itemname': 'market'})
pdf = pdf.reset_index().merge(temp4, how='inner', left_on='market', right_on='market', suffixes=('_item', '_market'))
pdf['month'] = pdf['date'].dt.month.astype(str)

train_set = df[df.date < '2020-01-01'].set_index(['itemname', 'date'])
test_set = df[df.date > '2020-01-01'][df.sector.isin(train_set.sector.unique())].set_index(['itemname', 'date'])
X_train, X_test, y_train, y_test = train_set.drop(['ror'], axis=1), test_set.drop(['ror'], axis=1),\
    train_set['ror'].copy(), test_set['ror'].copy()
pdf = pdf[pdf.sector.isin(X_train.sector.unique())].dropna().set_index(['itemname', 'date'])

cat_features = ["market", "sector", "area", "month"]
num_features = list(set(X_train.columns) - set(cat_features))
num_pipe = make_pipeline(StandardScaler(), Normalizer())
pre_pipe = make_column_transformer((num_pipe, num_features), (OneHotEncoder(), cat_features))
pre_pipe.fit(X_train)
pdf_trans = pre_pipe.transform(pdf)
predictions = model.predict(pdf_trans.toarray())
pdf['pred_ror'] = predictions
pdf['pred_ror_rank'] = pdf['pred_ror'].rank(ascending=False)
pdf = pdf.sort_values('pred_ror_rank')
display(ror_months, model, pdf.head(30))
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]
# 9
# TPOTRegressor(config_dict=None, crossover_rate=0.1,
#               cv=TimeSeriesSplit(max_train_size=None, n_splits=3),
#               disable_update_check=False, early_stop=None, generations=3,
#               log_file=None, max_eval_time_mins=5, max_time_mins=None,
#               memory='auto', mutation_rate=0.9, n_jobs=-1, offspring_size=None,
#               periodic_checkpoint_folder=None, population_size=10,
#               random_state=42, scoring=None, subsample=1.0, template=None,
#               use_dask=False, verbosity=3, warm_start=False)
#                          PER     PBR      PCR     PSR     ROE     ROA   OPROA  \
# itemname date
# 메카로      2020-11-20  -61.480   0.849   28.897   3.488  -1.410  -2.870  -0.511
# 삼호개발     2020-11-20    5.421   0.517   12.677   0.583  10.050   6.400   4.560
# CSA 코스믹  2020-11-20   14.517   3.310   34.527   2.208  30.190  15.640  12.523
# 클리오      2020-11-20   24.581   1.873   23.373   2.571   8.290   5.120   5.295
# KPX생명과학  2020-11-20    0.000   5.554   73.279   8.911   2.000   1.690   0.000
# 대웅제약     2020-11-20  116.304   1.997   43.496   1.416   1.820   1.020   1.766
# 한미약품     2020-11-20  -31.442   5.088   87.403   7.296  -0.168  -0.063  -0.065
# 모토닉      2020-11-20   33.929   0.875   24.204   2.917   2.720   2.540   3.660
# 덕산테코피아   2020-11-20   24.609   1.882   20.455   5.264  10.780   9.110   7.199
# 잉크테크     2020-11-20   11.605   1.493   17.984   1.587  13.180   4.760   6.484
# 윌비스      2020-11-20   24.375   0.808   16.446   0.746   0.035   0.012   0.030
# LG생활건강   2020-11-20   30.492   6.138   49.415   7.531   0.205   0.140   0.198
# 텔콘RF제약   2020-11-20  -12.771   5.332  -55.847  36.816 -40.470 -34.080   6.738
# 다우기술     2020-11-20    2.515   0.653    8.785   0.198  27.150   2.760   3.991
# 새로닉스     2020-11-20  -10.417   0.896  115.000   1.033  -8.490  -5.230  -4.164
# 코리아나     2020-11-20  234.583   2.383   87.969   4.837   1.220   0.810   1.688
# 뉴지랩      2020-11-20  -10.964   5.614  -39.058  12.561 -49.340 -29.200 -23.177
# 인팩       2020-11-20  -11.886   0.580    8.315   0.318  -4.870  -0.900  -0.136
# KC그린홀딩스  2020-11-20   -5.677   0.640   10.691   0.322 -11.200  -4.660  -2.902
# 해태제과식품   2020-11-20    5.540   0.819    7.473   0.688  17.660   5.630   8.693
# CJ씨푸드    2020-11-20  1.029460           27.0
# 삼성공조     2020-11-20  1.029342           28.0
# 알에프텍     2020-11-20  1.029332           29.0
# 인텔리안테크   2020-11-20  1.029204           30.0
#
# [30 rows x 77 columns]

# %%
pipe, X_test, y_test = split_fit(df, model=LGBMRegressor(random_state=42))
predictions = pipe.predict(pdf)
pdf['pred_ror'] = predictions
pdf['pred_ror_rank'] = pdf['pred_ror'].rank(ascending=False)
pdf = pdf.sort_values('pred_ror_rank')
display(ror_months, model, pdf.head(30))
# Out:
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\gsr27\Anaconda3\envs\ml_lab\lib\site-packages\sklearn\compose\_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 9
# TPOTRegressor(config_dict=None, crossover_rate=0.1,
#               cv=TimeSeriesSplit(max_train_size=None, n_splits=3),
#               disable_update_check=False, early_stop=None, generations=3,
#               log_file=None, max_eval_time_mins=5, max_time_mins=None,
#               memory='auto', mutation_rate=0.9, n_jobs=-1, offspring_size=None,
#               periodic_checkpoint_folder=None, population_size=10,
#               random_state=42, scoring=None, subsample=1.0, template=None,
#               use_dask=False, verbosity=3, warm_start=False)
#                          PER     PBR       PCR     PSR      ROE     ROA  \
# itemname date
# 광림       2020-11-20   -4.551   1.309    60.484   1.387  -27.770  -9.810
# 휴마시스     2020-11-20   10.570   8.766    39.181  16.032  102.580  68.380
# 씨젠       2020-11-20    9.111  11.736    16.882   8.080  157.860  93.820
# 바디텍메드    2020-11-20   11.326   5.961    20.235   7.389   60.100  49.380
# 대림제지     2020-11-20   -3.576   0.505     6.916   0.732  -13.870  -8.990
# 파나진      2020-11-20    0.000   7.099    29.570  18.004   19.200  15.280
# 한스바이오메드  2020-11-20  231.250   1.671    33.549   2.327    0.760   0.680
# 국일제지     2020-11-20  -47.500  10.881 -1646.667  12.506  -23.660 -10.480
# 네패스      2020-11-20  -21.320   3.773    28.886   4.268  -17.440  -5.610
# 모나리자     2020-11-20    0.000   3.105    30.385   1.715    3.750   3.140
# 녹십자엠에스   2020-11-20  187.500   6.504    74.661   6.901    0.038   0.022
# 앱클론      2020-11-20    0.000  13.201   144.836  30.943    9.490   6.780
# 엑세스바이오   2020-11-20  106.944  17.647   220.000  27.273   23.070  11.640
# 세운메디칼    2020-11-20   16.250   2.358    29.355   7.147   14.900  14.280
# 세하       2020-11-20    0.000   1.303     2.797   0.278   34.660   6.120
# 메타바이오메드  2020-11-20   25.580   1.280    75.395   2.018    5.360   2.410
# 대유에이피    2020-11-20   20.597   1.708    17.303   1.018    8.360   2.730
# 큐브엔터     2020-11-20  188.250   3.666    42.303   5.236    1.860   0.110
# 디엔에이링크   2020-11-20  -18.811  13.359   -76.368  29.806  -83.490 -44.820
# 옵티팜      2020-11-20    0.000   7.206  1275.000  18.750   -1.840  -1.550
# 대호에이엘    2020-11-20    0.000   2.359  -109.524   0.531  -12.620  -4.140
# 유진기업     2020-11-20    2.600   0.422     5.415   0.506   17.270   3.120
# 이수페타시스   2020-11-20   14.323   2.209    23.305   0.689   16.980   2.670
# 성신양회     2020-11-20    2.246   0.441     7.767   0.551   20.170   7.660
